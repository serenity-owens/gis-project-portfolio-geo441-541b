# %% [markdown]
# <a href="https://colab.research.google.com/github/serenity-owens/gis-project-portfolio-geo441-541b/blob/main/basic-mapping/projecting-geographic-data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Projecting Geographic Data**

# %% [markdown]
# Created by Serenity Owens
#
# 09/11/2025

# %% [markdown]
# ## **Get ready to start**
#
# - Click **`File/Save a copy in Drive`** to save a copy of this notebook to my own Google Drive

# %% [markdown]
# ## **Map of Minnesota Counties**

# %% [markdown]
# Below is a map of Minnesota counties prepared following the Assignment #3 Guide
#
# ```markdown
# [https://drive.google.com/file/d/13zd2oRMvU1GjzdbWb3U-9hMj9WXAtNGC/view?usp=sharing]
# ```
#
# Create a viewable link of the map.
# - Delete `view?usp=sharing`at the end of the link
# - Replace `/file/d/` with `/uc?export=view&id=`
#
#
# ```markdown
# [https://drive.google.com/uc?export=view&id=13zd2oRMvU1GjzdbWb3U-9hMj9WXAtNGC/]
# ```
#
# Insert the map below using the rendering syntax:
# ```markdown
# ![MN map](https://drive.google.com/uc?export=view&id=13zd2oRMvU1GjzdbWb3U-9hMj9WXAtNGC/)
# ```
#
# <mark>![MN map](https://drive.google.com/uc?export=view&id=13zd2oRMvU1GjzdbWb3U-9hMj9WXAtNGC)</mark>

# %% [markdown]
# ## **Coordinates of selected points in Minnesota map**
#
# | Point      | X coordinate (lon)  | Y coordinate (lat) |
# | ------- | --------------------- |------------------- |
# | Northeast corner of Ramsey County     | <mark>[92.99 W]</mark>  | <mark>[45.11 N]</mark> |

# %% [markdown]
# ## **Information of the coordinate systems**
#
# - By checking the **`Layer Properties`**, we can obtain the following info about the coordinate system used in map
#
#
# | Variable      | Information  |
# | ----------------------------- | -------------------------- |
# | Projection used in map     | <mark>[Transverse Mercator]</mark>  |
# | Projection zone number     | <mark>[UTM Zone 15N]</mark>    |
# | Geograpphic Coordinate System      | <mark>[NAD 1983]</mark>   |
# | Datum | <mark>[D North America 1983]</mark>|

# %% [markdown]
# ## **Save and share this notebook**
#
# Make sure the notebook is viewable by anyone with the link, then <mark>**submit the shareable link to Canvas for the Week 3 assignment.**</mark>

# %% [markdown]
# ## **Reference**
# - [Markdown cheat sheet](https://www.markdownguide.org/cheat-sheet/)
