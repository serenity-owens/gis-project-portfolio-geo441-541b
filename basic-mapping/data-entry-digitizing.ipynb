# %% [markdown]
# <a href="https://colab.research.google.com/github/serenity-owens/gis-project-portfolio-geo441-541b/blob/main/basic-mapping/data-entry-digitizing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Entry & Digitizing**

# %% [markdown]
# Created by Serenity Owens
#
#
#
#
# 09/23/22025

# %% [markdown]
# ## **Get ready to start**
#
# - Click **`File/Save a copy in Drive`** to save a copy of this notebook to your own Google Drive

# %% [markdown]
# ##**Digitized Township Map**

# %% [markdown]
# Below is a map of May Township prepared following the Week 4 Assignment Guide
#
# ```markdown
# [https://drive.google.com/file/d/1-zMlpmz9gAYhTM1QiKHAltDeiYFPtcBI/view?usp=sharing]
# ```
#
# Create a viewable link of the map.
# - Delete `/view?usp=sharing`at the end of the link
# - Replace `/file/d/` with `/uc?export=view&id=`
#
#
# ```markdown
# [https://drive.google.com/uc?export=view&id=1-zMlpmz9gAYhTM1QiKHAltDeiYFPtcBI/]
# ```
#
# Reminder of the rendering syntax:
# ```markdown
# ![township map](https://drive.google.com/uc?export=view&id=1-zMlpmz9gAYhTM1QiKHAltDeiYFPtcBI)
# ```
#
# <mark>![township map](https://drive.google.com/uc?export=view&id=1-zMlpmz9gAYhTM1QiKHAltDeiYFPtcBI)</mark>

# %% [markdown]
# ##**Digitized Subdivision Map**

# %% [markdown]
# Below is a map of the digitized subdivision prepared following the Week 4 Assignment Guide
#
# ```markdown
# [https://drive.google.com/file/d/15Y6fTVWZLaFOpfx3pj9pFl_2-ZyQN_6h/view?usp=sharing]
# ```
#
# Create a viewable link of the map.
# - Delete `/view?usp=sharing`at the end of the link
# - Replace `/file/d/` with `/uc?export=view&id=`
#
#
# ```markdown
# [https://drive.google.com/uc?export=view&id=15Y6fTVWZLaFOpfx3pj9pFl_2-ZyQN_6h]
# ```
#
# Reminder of the rendering syntax:
# ```markdown
# ![township map](https://drive.google.com/uc?export=view&id=15Y6fTVWZLaFOpfx3pj9pFl_2-ZyQN_6h)
# ```
#
# <mark>![township map](https://drive.google.com/uc?export=view&id=15Y6fTVWZLaFOpfx3pj9pFl_2-ZyQN_6h)</mark>

# %% [markdown]
# ## **Save and share this notebook**
#
# Make sure the notebook is viewable by anyone with the link, then <mark>**submit the shareable link to Canvas for the Week 4 Assignment.**</mark>

# %% [markdown]
# ## **References**
# - [Markdown cheat sheet](https://www.markdownguide.org/cheat-sheet/)
