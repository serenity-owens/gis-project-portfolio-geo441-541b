# %% [markdown]
# <a href="https://colab.research.google.com/github/serenity-owens/gis-project-portfolio-geo441-541b/blob/main/spatial-data-analysis/vector-data-spatial-analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Vector Data / Spatial Analysis**

# %% [markdown]
# Created by Serenity Owens
#
# 10/05/25

# %% [markdown]
# ## **Get ready to start**
#
# - Click **`File/Save a copy in Drive`** to save a copy of this notebook to your own Google Drive

# %% [markdown]
# ## **Part 1: John Snow Cholera Maps**
#
# ---

# %% [markdown]
# ### **1a: Water Pump Buffer Map**

# %% [markdown]
# Below is a map of cholera deaths inside a 100m buffer of water pumps in the Soho District of London, 1854.
#
# ```markdown
# https://drive.google.com/file/d/1rkdl3mqvNVuTQG0f1r2beHZMiig1AUIx/view?usp=sharing```
#
# Create a viewable link of the map.
# - Delete `/view?usp=sharing` at the end of the link
# - Replace `/file/d/` with `/uc?export=view&id=`
#
#
# ```markdown
# https://drive.google.com/uc?export=view&id=1rkdl3mqvNVuTQG0f1r2beHZMiig1AUIx```
#
# Reminder of the rendering syntax:
# ```markdown
# ![pump buffer](https://drive.google.com/uc?export=view&id=1rkdl3mqvNVuTQG0f1r2beHZMiig1AUIx)
# ```
#
# <mark>Insert the map below:</mark>
# ![pump buffer](https://drive.google.com/uc?export=view&id=1rkdl3mqvNVuTQG0f1r2beHZMiig1AUIx)

# %% [markdown]
# ### **1b: Cholera Deaths Heatmap**

# %% [markdown]
# Below is a heatmap of cholera deaths in the Soho District of London, 1854.
#
# ```markdown
# https://drive.google.com/file/d/1VPEuK8O5iCdcTFeUbHNvQeoCzpp90orx/view?usp=sharing```
#
# Create a viewable link of the map.
# - Delete `/view?usp=sharing` at the end of the link
# - Replace `/file/d/` with `/uc?export=view&id=`
#
#
# ```markdown
# https://drive.google.com/uc?export=view&id=1VPEuK8O5iCdcTFeUbHNvQeoCzpp90orx```
#
# Reminder of the rendering syntax:
# ```markdown
# https://drive.google.com/uc?export=view&id=1VPEuK8O5iCdcTFeUbHNvQeoCzpp90orx
# ```
#
# <mark>Insert the map below:</mark>
# ![heatmap](https://drive.google.com/uc?export=view&id=1VPEuK8O5iCdcTFeUbHNvQeoCzpp90orx)

# %% [markdown]
# ## **Part 2: Campgrounds**
#
# ---

# %% [markdown]
# Below is a map of sites suitable for campgrounds on private land near Hugo Lake, MN.
#
# ```markdown
# [https://drive.google.com/file/d/1lSz6WZhHEZ6UKZCE-9nme32OBkJYhw2X/view?usp=sharing]
# ```
#
# Create a viewable link of the map.
# - Delete `/view?usp=sharing` at the end of the link
# - Replace `/file/d/` with `/uc?export=view&id=`
#
#
# ```markdown
# [https://drive.google.com/uc?export=view&id=1lSz6WZhHEZ6UKZCE-9nme32OBkJYhw2X]
# ```
#
# Reminder of the rendering syntax:
# ```markdown
# ![private land](https://drive.google.com/uc?export=view&id=1lSz6WZhHEZ6UKZCE-9nme32OBkJYhw2X)
# ```
#
# <mark>Insert the map below:</mark>
# ![private land](https://drive.google.com/uc?export=view&id=1lSz6WZhHEZ6UKZCE-9nme32OBkJYhw2X)

# %% [markdown]
# ## **Save and share this notebook**
#
# Make sure that your images are all rendering and then share the notebook so that it is viewable by anyone with the link.
#
# <mark>**Submit the shareable link to Canvas for the Week 10 Assignment.**</mark>
