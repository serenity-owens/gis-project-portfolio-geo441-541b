# %% [markdown]
# <a href="https://colab.research.google.com/github/serenity-owens/gis-project-portfolio-geo441-541b/blob/main/spatial-data-analysis/census-data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Census Data**

# %% [markdown]
# Created by Serenity Owens
#
# 11/22/2025

# %% [markdown]
# ## **Get ready to start**
#
# - Click **`File/Save a copy in Drive`** to save a copy of this notebook to your own Google Drive

# %% [markdown]
# ## **1. Smartphone Use in Ohio, 2023**
#
# ---

# %% [markdown]
# Below is a map of smartphone use in Ohio using data from the 2023 American Community Survey (5-Year Estimates).
#
# ```markdown
# https://drive.google.com/file/d/19fHcLa0TLCIjVpC7MpzDY3BD3D2X8pN3/view?usp=sharing
# ```
#
# Create a viewable link of the map.
# - Delete `/view?usp=sharing` at the end of the link
# - Replace `/file/d/` with `/uc?export=view&id=`
#
#
# ```markdown
# https://drive.google.com/uc?export=view&id=19fHcLa0TLCIjVpC7MpzDY3BD3D2X8pN3
# ```
#
# Reminder of the rendering syntax:
# ```markdown
# ![smartphone](https://drive.google.com/uc?export=view&id=19fHcLa0TLCIjVpC7MpzDY3BD3D2X8pN3)
# ```
#
# <mark>Insert the map below:</mark>
# ![smartphone](https://drive.google.com/uc?export=view&id=19fHcLa0TLCIjVpC7MpzDY3BD3D2X8pN3)

# %% [markdown]
# ### **2. Final Project Draft Map**

# %% [markdown]
# Below is a draft map of a final project map.
#
# ```markdown
# https://drive.google.com/file/d/16QRMdWhe3_gtnUE_Nka6KqCOXetYlblL/view?usp=sharing
# ```
#
# Create a viewable link of the map.
# - Delete `/view?usp=sharing` at the end of the link
# - Replace `/file/d/` with `/uc?export=view&id=`
#
#
# ```markdown
# https://drive.google.com/uc?export=view&id=16QRMdWhe3_gtnUE_Nka6KqCOXetYlblL
# ```
#
# Reminder of the rendering syntax:
# ```markdown
# ![draft](https://drive.google.com/uc?export=view&id=16QRMdWhe3_gtnUE_Nka6KqCOXetYlblL)
# ```
#
# <mark>Insert the map below:</mark>
# ![draft](https://drive.google.com/uc?export=view&id=16QRMdWhe3_gtnUE_Nka6KqCOXetYlblL)

# %% [markdown]
# ## **Save and share this notebook**
#
# Make sure that your images are all rendering and then share the notebook so that it is viewable by anyone with the link.
#
# <mark>**Submit the shareable link to Canvas for the Week 12 & 13 Assignment.**</mark>
